# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = r"C:\Users\MSI\Desktop\project For Me\Amazon Prime Movies and TV Shows\projet 1\amazon.xlsx"
df = pd.read_excel(url)

print(df)
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9682   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9683   s9665  TV Show            Planet Patrol              NaN
# 9684   s9666    Movie                  Outpost     Steve Barker
# 9685   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9686   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021        2014.0    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# # Tail

# %%
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9682   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9683   s9665  TV Show            Planet Patrol              NaN
# 9684   s9666    Movie                  Outpost     Steve Barker
# 9685   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9686   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9682                           Leo Gorcey, Bobby Jordan     NaN        NaN
# 9683  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaN
# 9684  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaN
# 9685  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaN
# 9686  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaN
#
#       release_year rating   duration                listed_in  \
# 9682        1940.0     7+     60 min                   Comedy
# ...

# %%
df.shape
# Out:
# (9687, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
df["director"].unique()
# Out:
# array(['Don McKellar', 'Girish Joshi', 'Josh Webber', ...,
#        'John-Paul Davidson, Stephen Warbeck', 'Emily Skye',
#        'Steve Barker'], dtype=object)

# %%
df.nunique()
# Out:
# show_id         9684
# type              10
# title           9671
# director        5774
# cast            7928
# country           86
# date_added        84
# release_year     100
# rating            24
# duration         219
# listed_in        518
# description     9413
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   9666.000000
# mean    2008.341196
# std       18.923990
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
df["director"].value_counts()
# Out:
# director
# Mark Knight              113
# Cannis Holder             61
# Moonbug Entertainment     37
# Jay Chapman               34
# Arthur van Merwijk        30
#                         ...
# K. Subash                  1
# Robert Cuffley             1
# J. Sabarish                1
# Robert Ramirez             1
# Steve Barker               1
# Name: count, Length: 5774, dtype: int64

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 9682    False  False  False     False  False     True        True
# 9683    False  False  False      True  False     True        True
# 9684    False  False  False     False  False     True        True
# 9685    False  False  False      True  False     True        True
# 9686    False  False  False     False  False     True        True
#
#       release_year  rating  duration  listed_in  description
# 0            False    True     False      False        False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9687 entries, 0 to 9686
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9687 non-null   object
#  1   type          9677 non-null   object
#  2   title         9671 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8434 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9666 non-null   float64
#  8   rating        9329 non-null   object
#  9   duration      9666 non-null   object
#  10  listed_in     9666 non-null   object
#  11  description   9666 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 908.3+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2021.0    1442
# 2020.0     961
# 2019.0     929
# 2018.0     623
# 2017.0     562
#           ...
# 1922.0       2
# 1926.0       2
# 1924.0       1
# 1923.0       1
# 1927.0       1
# Name: count, Length: 100, dtype: int64

# %%
df.type.value_counts()
# Out:
# type
# Movie                                                                                      7814
# TV Show                                                                                    1854
#  once he sees one. Once inside the bath... there awaits a little piece of heaven."            2
#  the blazing sun                                                                              1
#  Iori runs into a group of tough guys playing strip rock-paper-scissors                       1
#  17-year-old Arato Endo meets the android Lacia and becomes her owner.                        1
#  and fight to gain each other's abilities.                                                    1
#  """"BANANA FISH"""". That is the word his brother                                            1
#  the threat of the Empire looms once again.                                                   1
#  will Mahmut be able to thwart the threat of Balt-Rhein and bring peace to his nation?"       1
# ...

# %%
df.type.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='type'>

# %%
df[(df["type"] == "Movie") & (df["country"] == "United Kingdom")].head(3)
# Out:
#    show_id   type                              title        director  \
# 4       s5  Movie                      Monster Maker    Giles Foster
# 5       s6  Movie              Living With Dinosaurs    Paul Weiland
# 14     s15  Movie  Elon Musk: The Real Life Iron Man  Sonia Anderson
#
#                                                  cast         country  \
# 4   Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5   Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 14  Elon Musk, Per Wimmer, Julie Anderson-Ankenbra...  United Kingdom
#
#         date_added  release_year rating duration       listed_in  \
# 4   March 30, 2021        1989.0    NaN   45 min  Drama, Fantasy
# 5   March 30, 2021        1989.0    NaN   52 min   Fantasy, Kids
# 14     May 2, 2021        2018.0    NaN   74 min     Documentary
#
#                                           description
# 4   Teenage Matt Banting wants to work with a famo...
# ...

# %%
df[(df["type"] == "Movie") & (df["director"] == "Paul Weiland")].head(3)
# Out:
#   show_id   type                  title      director  \
# 5      s6  Movie  Living With Dinosaurs  Paul Weiland
#
#                                                 cast         country  \
# 5  Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
#
#        date_added  release_year rating duration      listed_in  \
# 5  March 30, 2021        1989.0    NaN   52 min  Fantasy, Kids
#
#                                          description
# 5  The story unfolds in a an English seaside town...

# %%
df["director"].value_counts().head(3)
# Out:
# director
# Mark Knight              113
# Cannis Holder             61
# Moonbug Entertainment     37
# Name: count, dtype: int64

# %%
sns.stripplot(x='release_year', y='rating', data=df, palette='viridis')
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_376\1654611637.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='release_year', y='rating', data=df, palette='viridis')
# <Axes: xlabel='release_year', ylabel='rating'>
